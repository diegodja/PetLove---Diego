# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
from matplotlib import figure as f
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
dados = pd.read_csv('data-test-analytics.csv')

# %%
dados
# Out:
#                                         id          created_at  \
# 6779  bc16f8f9-defd-495e-8a1d-e991eef5bffc 2015-12-23 09:25:41
# 918   304850c3-db43-4949-a767-b8e978b92aae 2015-12-23 13:16:56
# 6701  e8146fe9-58bc-4a4e-a06a-14688e4166d5 2015-12-23 16:45:17
# 4611  96ff4efd-442d-4b00-9113-451d349f3201 2015-12-25 08:54:59
# 1603  1d285631-45cc-485b-9a1c-768d68f80b7b 2015-12-25 09:09:41
# ...                                    ...                 ...
# 6184  c3669b09-33cb-4f03-a7dc-abacdec2788a 2020-12-20 21:34:07
# 8298  b49b8c0f-0afe-48cc-a5b6-cd2f87897cce 2020-12-21 13:10:43
# 2855  921d5583-5b48-486f-b74c-699c8da9e396 2020-12-21 22:37:23
# 7427  ce6eb1de-2248-4632-9f6c-ff0c1604cc59 2020-12-21 23:58:28
# 8167  d711559b-67a1-499a-917a-d24fc30aeaad 2020-12-22 06:31:55
#
#                       updated_at          deleted_at  \
# 6779  2020-11-21 13:27:52.836616                 NaT
# 918   2020-11-12 13:27:51.591092                 NaT
# 6701  2020-11-21 13:27:52.820011                 NaT
# 4611  2020-01-18 04:35:27.000000 2020-01-18 04:35:27
# 1603  2020-11-24 13:27:51.733942                 NaT
# ...                          ...                 ...
# 6184  2020-11-19 13:27:52.710868                 NaT
# 8298  2020-11-16 13:27:53.154925                 NaT
# 2855  2020-11-15 13:27:52.008637                 NaT
# 7427  2020-11-19 13:27:52.971908                 NaT
# 8167  2020-12-22 07:56:42.000000 2020-12-22 07:56:42
#
#                              name_hash                        email_hash  \
# 6779  cc1c70326f6ae08b9a258569da0531fc  816623dd086c3605de961123ccb11ce3
# 918   a070687322986ccaab94070092e60c84  affc86f5165a0341e27ef10bca2e488a
# 6701  701ea73231d265574443b0a083da05a2  75a034e48aeafa48c8fbab912333bbe2
# 4611  a038a6e9bd8b2d4eccb3f001cd4cf571  1dde352707f4b2ec244392f130e5ecb2
# 1603  6f4b0825007f8619b5de83a97f7af0c0  3fd2b34871af421fd02d48f2db4278c8
# ...                                ...                               ...
# 6184  4ce2bed26844c98a97d96f87f2ed65a0  6aa47da6a8f31ee8b99f32e934a55786
# 8298  070fd1eaeade04f72cca938c3349bc7a  8332159921ee099ba1a12cac7ea20570
# 2855  4cef9247193671fe391190d72c89dcff  3bf4b5b9830bbc067307a5d96b3a4ac4
# 7427  ba7d76e5040ddaf06820217e1ac1e956  3880ae1446c61ad8628434014a96d82d
# 8167  55703e2759fb57f500f3c27b5019031b  929a2d3cf83d62e688918feca2d9fe39
#
#                           address_hash                  birth_date    status  \
# 6779  056e0bd2370431102b8472ba9926f180  1994-07-27 00:00:00.000000    active
# 918   32ebdfc126334278a2c8423fe9a9a54b  1960-07-09 00:00:00.000000    active
# 6701  96dc7e26cc5c28026fa5af9b2103ee19  1947-12-01 00:00:00.000000    active
# 4611  5c3520e8f4e6263bbc214711873d0a7b  1959-03-06 00:00:00.000000  canceled
# 1603  0f857e17c1d5782ade18cce6d46a4f90  1977-09-03 00:00:00.000000    active
# ...                                ...                         ...       ...
# 6184  40fbac9389c7f51103cb25cc2566a1b4  1983-12-04 00:00:00.000000    paused
# 8298  7d7bcf66df50aa779b45cf3538a51782  1952-05-01 00:00:00.000000    active
# 2855  10710a16d1dfc6570170970a2ae57e74  1965-02-19 00:00:00.000000    active
# 7427  d85f8ffe5e2fedca23e8fc60daf5d37f  1966-04-24 00:00:00.000000    active
# 8167  7b0f8cf910282b24585aed003f864907  1982-06-15 00:00:00.000000  canceled
#
#       version  ...          last_date_purchase average_ticket num_items  \
# 6779   0.18.8  ...  2020-11-21 13:27:52.836616     216.522235         8
# 918    3.48.6  ...  2020-11-12 13:27:51.591092     197.631659        14
# 6701   5.19.6  ...  2020-11-21 13:27:52.820011     211.398749        18
# 4611   4.43.9  ...  2019-03-09 18:09:08.000000     247.079597         9
# 1603   4.20.9  ...  2020-11-24 13:27:51.733942     231.166215        12
# ...       ...  ...                         ...            ...       ...
# 6184  3.61.11  ...  2020-11-19 13:27:52.710868     205.328740        12
# 8298    1.8.6  ...  2020-11-16 13:27:53.154925     248.375527         4
# 2855  3.19.11  ...  2020-11-15 13:27:52.008637     238.890941         9
# 7427   2.31.0  ...  2020-11-19 13:27:52.971908     244.557680         9
# 8167   2.14.6  ...  2020-12-22 07:00:01.000000     224.360765         6
#
#       all_revenue  recency  marketing_source  Criado  created_at_YM  \
# 6779  1732.177883       31    organic_search       1         201512
# 918   2766.843222       40            direct       1         201512
# 6701  3805.177474       31       paid_search       1         201512
# 4611  2223.716372      653            direct       1         201512
# 1603  2773.994585       28    organic_search       1         201512
# ...           ...      ...               ...     ...            ...
# 6184  2463.944882       33              none       1         202012
# 8298   993.502106       36       paid_search       1         202012
# 2855  2150.018465       37       paid_search       1         202012
# 7427  2201.019121       33    organic_search       1         202012
# 8167  1346.164593        0    organic_search       1         202012
#
#      deleted_at_YM     X
# 6779           NaN     0
# 918            NaN     1
# 6701           NaN     2
# 4611        202001     3
# 1603           NaN     4
# ...            ...   ...
# 6184           NaN  9995
# 8298           NaN  9996
# 2855           NaN  9997
# 7427           NaN  9998
# 8167        202012  9999
#
# [10000 rows x 23 columns]

# %%
dados.sort_values(by=['created_at'], inplace=True)

# %%
dados.head()
# Out:
#                                         id                  created_at  \
# 6779  bc16f8f9-defd-495e-8a1d-e991eef5bffc  2015-12-23 09:25:41.000000
# 918   304850c3-db43-4949-a767-b8e978b92aae  2015-12-23 13:16:56.000000
# 6701  e8146fe9-58bc-4a4e-a06a-14688e4166d5  2015-12-23 16:45:17.000000
# 4611  96ff4efd-442d-4b00-9113-451d349f3201  2015-12-25 08:54:59.000000
# 1603  1d285631-45cc-485b-9a1c-768d68f80b7b  2015-12-25 09:09:41.000000
#
#                       updated_at                  deleted_at  \
# 6779  2020-11-21 13:27:52.836616                         NaN
# 918   2020-11-12 13:27:51.591092                         NaN
# 6701  2020-11-21 13:27:52.820011                         NaN
# 4611  2020-01-18 04:35:27.000000  2020-01-18 04:35:27.000000
# 1603  2020-11-24 13:27:51.733942                         NaN
#
#                              name_hash                        email_hash  \
# 6779  cc1c70326f6ae08b9a258569da0531fc  816623dd086c3605de961123ccb11ce3
# 918   a070687322986ccaab94070092e60c84  affc86f5165a0341e27ef10bca2e488a
# 6701  701ea73231d265574443b0a083da05a2  75a034e48aeafa48c8fbab912333bbe2
# 4611  a038a6e9bd8b2d4eccb3f001cd4cf571  1dde352707f4b2ec244392f130e5ecb2
# 1603  6f4b0825007f8619b5de83a97f7af0c0  3fd2b34871af421fd02d48f2db4278c8
#
#                           address_hash                  birth_date    status  \
# 6779  056e0bd2370431102b8472ba9926f180  1994-07-27 00:00:00.000000    active
# 918   32ebdfc126334278a2c8423fe9a9a54b  1960-07-09 00:00:00.000000    active
# 6701  96dc7e26cc5c28026fa5af9b2103ee19  1947-12-01 00:00:00.000000    active
# 4611  5c3520e8f4e6263bbc214711873d0a7b  1959-03-06 00:00:00.000000  canceled
# 1603  0f857e17c1d5782ade18cce6d46a4f90  1977-09-03 00:00:00.000000    active
#
#      version                city state         neighborhood  \
# 6779  0.18.8   Nogueira Paulista    TO      Santo Agostinho
# 918   3.48.6              da Luz    MT    Granja De Freitas
# 6701  5.19.6               Nunes    BA  Vila Novo São Lucas
# 4611  4.43.9   Castro das Pedras    CE              Acaiaca
# 1603  4.20.9              Castro    CE            Aeroporto
#
#               last_date_purchase  average_ticket  num_items  all_revenue  \
# 6779  2020-11-21 13:27:52.836616      216.522235          8  1732.177883
# 918   2020-11-12 13:27:51.591092      197.631659         14  2766.843222
# 6701  2020-11-21 13:27:52.820011      211.398749         18  3805.177474
# 4611  2019-03-09 18:09:08.000000      247.079597          9  2223.716372
# 1603  2020-11-24 13:27:51.733942      231.166215         12  2773.994585
#
#       recency marketing_source
# 6779       31   organic_search
# 918        40           direct
# 6701       31      paid_search
# 4611      653           direct
# 1603       28   organic_search

# %%
dados['Criado'] = 1

# %%
dados['created_at'] = pd.to_datetime(dados['created_at'], errors='coerce')
dados['created_at_YM'] = dados['created_at'].dt.strftime('%Y%m')

# %%
dados['deleted_at'] = pd.to_datetime(dados['deleted_at'], errors='coerce')
dados['deleted_at_YM'] = dados['deleted_at'].dt.strftime('%Y%m')

# %%
Deletados = dados.groupby('deleted_at_YM')[['id']].count()
Deletados = Deletados.add_suffix('_Count').reset_index()

# %%
Deletados
# Out:
#    deleted_at_YM  id_Count
# 0         201605         1
# 1         201606         3
# 2         201607         1
# 3         201610         1
# 4         201611         2
# 5         201612         3
# 6         201701         1
# 7         201702         2
# 8         201703         6
# 9         201704         2
# 10        201705         2
# 11        201706         3
# 12        201707         5
# 13        201709         4
# 14        201710         2
# 15        201711         4
# 16        201712         5
# 17        201801         6
# 18        201802         7
# 19        201803         3
# 20        201804         5
# 21        201805         3
# 22        201806         6
# 23        201807         4
# 24        201808         9
# 25        201809         5
# 26        201810         9
# 27        201811        10
# 28        201812         8
# 29        201901         6
# 30        201902         7
# 31        201903        11
# 32        201904        12
# 33        201905         8
# 34        201906        10
# 35        201907         4
# 36        201908         7
# 37        201909        12
# 38        201910         8
# 39        201911        11
# 40        201912        19
# 41        202001        22
# 42        202002        11
# 43        202003        11
# 44        202004        23
# 45        202005        15
# 46        202006        20
# 47        202007        27
# 48        202008        15
# 49        202009        20
# 50        202010        28
# 51        202011        38
# 52        202012        32

# %%
Deletados.columns = ['created_at_YM', 'Deletados']

# %%
Deletados
# Out:
#    created_at_YM  Deletados
# 0         201605          1
# 1         201606          3
# 2         201607          1
# 3         201610          1
# 4         201611          2
# 5         201612          3
# 6         201701          1
# 7         201702          2
# 8         201703          6
# 9         201704          2
# 10        201705          2
# 11        201706          3
# 12        201707          5
# 13        201709          4
# 14        201710          2
# 15        201711          4
# 16        201712          5
# 17        201801          6
# 18        201802          7
# 19        201803          3
# 20        201804          5
# 21        201805          3
# 22        201806          6
# 23        201807          4
# 24        201808          9
# 25        201809          5
# 26        201810          9
# 27        201811         10
# 28        201812          8
# 29        201901          6
# 30        201902          7
# 31        201903         11
# 32        201904         12
# 33        201905          8
# 34        201906         10
# 35        201907          4
# 36        201908          7
# 37        201909         12
# 38        201910          8
# 39        201911         11
# 40        201912         19
# 41        202001         22
# 42        202002         11
# 43        202003         11
# 44        202004         23
# 45        202005         15
# 46        202006         20
# 47        202007         27
# 48        202008         15
# 49        202009         20
# 50        202010         28
# 51        202011         38
# 52        202012         32

# %%
Churn = dados.groupby('created_at_YM')[['id']].count()
Churn = Churn.reset_index()

# %%
Churn
# Out:
#    created_at_YM   id
# 0         201512   39
# 1         201601  197
# 2         201602  166
# 3         201603  180
# 4         201604  154
# ..           ...  ...
# 56        202008  174
# 57        202009  165
# 58        202010  169
# 59        202011  176
# 60        202012  112
#
# [61 rows x 2 columns]

# %%
Churn = pd.merge(Churn, Deletados, on="created_at_YM")

# %%
Churn.columns = ['created_at_YM', 'Criado', 'Deletados']
Churn
# Out:
#    created_at_YM  Criado  Deletados
# 0         201605     155          1
# 1         201606     139          3
# 2         201607     174          1
# 3         201610     190          1
# 4         201611     186          2
# 5         201612     191          3
# 6         201701     165          1
# 7         201702     145          2
# 8         201703     185          6
# 9         201704     169          2
# 10        201705     169          2
# 11        201706     170          3
# 12        201707     171          5
# 13        201709     161          4
# 14        201710     169          2
# 15        201711     144          4
# 16        201712     164          5
# 17        201801     188          6
# 18        201802     156          7
# 19        201803     172          3
# 20        201804     142          5
# 21        201805     157          3
# 22        201806     168          6
# 23        201807     153          4
# 24        201808     161          9
# 25        201809     162          5
# 26        201810     183          9
# 27        201811     170         10
# 28        201812     163          8
# 29        201901     159          6
# 30        201902     158          7
# 31        201903     200         11
# 32        201904     164         12
# 33        201905     151          8
# 34        201906     180         10
# 35        201907     164          4
# 36        201908     167          7
# 37        201909     151         12
# 38        201910     195          8
# 39        201911     142         11
# 40        201912     165         19
# 41        202001     164         22
# 42        202002     154         11
# 43        202003     180         11
# 44        202004     159         23
# 45        202005     179         15
# 46        202006     159         20
# 47        202007     159         27
# 48        202008     174         15
# 49        202009     165         20
# 50        202010     169         28
# 51        202011     176         38
# 52        202012     112         32

# %%
Churn['DeletadoAcumulado'] = Churn['Deletados'].cumsum()

# %%
Churn['CriadoAcumulado'] = Churn['Criado'].cumsum()

# %%
Churn['SaldoAcumulado'] = Churn['CriadoAcumulado'] - Churn['DeletadoAcumulado']

# %%
Churn
# Out:
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 0         201605     155          1                  1              155
# 1         201606     139          3                  4              294
# 2         201607     174          1                  5              468
# 3         201610     190          1                  6              658
# 4         201611     186          2                  8              844
# 5         201612     191          3                 11             1035
# 6         201701     165          1                 12             1200
# 7         201702     145          2                 14             1345
# 8         201703     185          6                 20             1530
# 9         201704     169          2                 22             1699
# 10        201705     169          2                 24             1868
# 11        201706     170          3                 27             2038
# 12        201707     171          5                 32             2209
# 13        201709     161          4                 36             2370
# 14        201710     169          2                 38             2539
# 15        201711     144          4                 42             2683
# 16        201712     164          5                 47             2847
# 17        201801     188          6                 53             3035
# 18        201802     156          7                 60             3191
# 19        201803     172          3                 63             3363
# 20        201804     142          5                 68             3505
# 21        201805     157          3                 71             3662
# 22        201806     168          6                 77             3830
# 23        201807     153          4                 81             3983
# 24        201808     161          9                 90             4144
# 25        201809     162          5                 95             4306
# 26        201810     183          9                104             4489
# 27        201811     170         10                114             4659
# 28        201812     163          8                122             4822
# 29        201901     159          6                128             4981
# 30        201902     158          7                135             5139
# 31        201903     200         11                146             5339
# 32        201904     164         12                158             5503
# 33        201905     151          8                166             5654
# 34        201906     180         10                176             5834
# 35        201907     164          4                180             5998
# 36        201908     167          7                187             6165
# 37        201909     151         12                199             6316
# 38        201910     195          8                207             6511
# 39        201911     142         11                218             6653
# 40        201912     165         19                237             6818
# 41        202001     164         22                259             6982
# 42        202002     154         11                270             7136
# 43        202003     180         11                281             7316
# 44        202004     159         23                304             7475
# 45        202005     179         15                319             7654
# 46        202006     159         20                339             7813
# 47        202007     159         27                366             7972
# 48        202008     174         15                381             8146
# 49        202009     165         20                401             8311
# 50        202010     169         28                429             8480
# 51        202011     176         38                467             8656
# 52        202012     112         32                499             8768
#
#     SaldoAcumulado
# 0              154
# 1              290
# 2              463
# 3              652
# 4              836
# 5             1024
# 6             1188
# 7             1331
# 8             1510
# 9             1677
# 10            1844
# 11            2011
# 12            2177
# 13            2334
# 14            2501
# 15            2641
# 16            2800
# 17            2982
# 18            3131
# 19            3300
# 20            3437
# 21            3591
# 22            3753
# 23            3902
# 24            4054
# 25            4211
# 26            4385
# 27            4545
# 28            4700
# 29            4853
# 30            5004
# 31            5193
# 32            5345
# 33            5488
# 34            5658
# 35            5818
# 36            5978
# 37            6117
# 38            6304
# 39            6435
# 40            6581
# 41            6723
# 42            6866
# 43            7035
# 44            7171
# 45            7335
# 46            7474
# 47            7606
# 48            7765
# 49            7910
# 50            8051
# 51            8189
# 52            8269

# %%
start_date = "2017-01-01"
end_date = "2029-12-31"

# %%
after_start_date = Churn["created_at_YM"] >= start_date
before_end_date = Churn["created_at_YM"] <= end_date

# %%
between_two_dates = after_start_date & before_end_date

# %%
Churn = Churn.loc[between_two_dates]

# %%
Churn['Churn'] = Churn['Deletados']/Churn['SaldoAcumulado']
# Out:
# <ipython-input-59-b01d579647f6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Churn['Churn'] = Churn['Deletados']/Churn['SaldoAcumulado']

# %%
Churn.head()
# Out:
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 6         201701     165          1                 12             1200
# 7         201702     145          2                 14             1345
# 8         201703     185          6                 20             1530
# 9         201704     169          2                 22             1699
# 10        201705     169          2                 24             1868
#
#     SaldoAcumulado     Churn
# 6             1188  0.000842
# 7             1331  0.001503
# 8             1510  0.003974
# 9             1677  0.001193
# 10            1844  0.001085

# %%
Churn.tail()
# Out:
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 48        202008     174         15                381             8146
# 49        202009     165         20                401             8311
# 50        202010     169         28                429             8480
# 51        202011     176         38                467             8656
# 52        202012     112         32                499             8768
#
#     SaldoAcumulado     Churn
# 48            7765  0.001932
# 49            7910  0.002528
# 50            8051  0.003478
# 51            8189  0.004640
# 52            8269  0.003870

# %%
Churn['Churn'].plot(kind="bar")
plt.title('Subscriber Churn')
plt.xlabel('# of months from May, 2016')
plt.ylabel('Churn')
plt.show()

# %%
Churn['Churn%'] = pd.Series(["{0:.2f}%".format(val * 100) for val in Churn['Churn']], index = Churn.index)
# Out:
# <ipython-input-63-1838f5070ad8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Churn['Churn%'] = pd.Series(["{0:.2f}%".format(val * 100) for val in Churn['Churn']], index = Churn.index)

# %%
Churn
# Out:
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 6         201701     165          1                 12             1200
# 7         201702     145          2                 14             1345
# 8         201703     185          6                 20             1530
# 9         201704     169          2                 22             1699
# 10        201705     169          2                 24             1868
# 11        201706     170          3                 27             2038
# 12        201707     171          5                 32             2209
# 13        201709     161          4                 36             2370
# 14        201710     169          2                 38             2539
# 15        201711     144          4                 42             2683
# 16        201712     164          5                 47             2847
# 17        201801     188          6                 53             3035
# 18        201802     156          7                 60             3191
# 19        201803     172          3                 63             3363
# 20        201804     142          5                 68             3505
# 21        201805     157          3                 71             3662
# 22        201806     168          6                 77             3830
# 23        201807     153          4                 81             3983
# 24        201808     161          9                 90             4144
# 25        201809     162          5                 95             4306
# 26        201810     183          9                104             4489
# 27        201811     170         10                114             4659
# 28        201812     163          8                122             4822
# 29        201901     159          6                128             4981
# 30        201902     158          7                135             5139
# 31        201903     200         11                146             5339
# 32        201904     164         12                158             5503
# 33        201905     151          8                166             5654
# 34        201906     180         10                176             5834
# 35        201907     164          4                180             5998
# 36        201908     167          7                187             6165
# 37        201909     151         12                199             6316
# 38        201910     195          8                207             6511
# 39        201911     142         11                218             6653
# 40        201912     165         19                237             6818
# 41        202001     164         22                259             6982
# 42        202002     154         11                270             7136
# 43        202003     180         11                281             7316
# 44        202004     159         23                304             7475
# 45        202005     179         15                319             7654
# 46        202006     159         20                339             7813
# 47        202007     159         27                366             7972
# 48        202008     174         15                381             8146
# 49        202009     165         20                401             8311
# 50        202010     169         28                429             8480
# 51        202011     176         38                467             8656
# 52        202012     112         32                499             8768
#
#     SaldoAcumulado     Churn Churn%
# 6             1188  0.000842  0.08%
# 7             1331  0.001503  0.15%
# 8             1510  0.003974  0.40%
# 9             1677  0.001193  0.12%
# 10            1844  0.001085  0.11%
# 11            2011  0.001492  0.15%
# 12            2177  0.002297  0.23%
# 13            2334  0.001714  0.17%
# 14            2501  0.000800  0.08%
# 15            2641  0.001515  0.15%
# 16            2800  0.001786  0.18%
# 17            2982  0.002012  0.20%
# 18            3131  0.002236  0.22%
# 19            3300  0.000909  0.09%
# 20            3437  0.001455  0.15%
# 21            3591  0.000835  0.08%
# 22            3753  0.001599  0.16%
# 23            3902  0.001025  0.10%
# 24            4054  0.002220  0.22%
# 25            4211  0.001187  0.12%
# 26            4385  0.002052  0.21%
# 27            4545  0.002200  0.22%
# 28            4700  0.001702  0.17%
# 29            4853  0.001236  0.12%
# 30            5004  0.001399  0.14%
# 31            5193  0.002118  0.21%
# 32            5345  0.002245  0.22%
# 33            5488  0.001458  0.15%
# 34            5658  0.001767  0.18%
# 35            5818  0.000688  0.07%
# 36            5978  0.001171  0.12%
# 37            6117  0.001962  0.20%
# 38            6304  0.001269  0.13%
# 39            6435  0.001709  0.17%
# 40            6581  0.002887  0.29%
# 41            6723  0.003272  0.33%
# 42            6866  0.001602  0.16%
# 43            7035  0.001564  0.16%
# 44            7171  0.003207  0.32%
# 45            7335  0.002045  0.20%
# 46            7474  0.002676  0.27%
# 47            7606  0.003550  0.35%
# 48            7765  0.001932  0.19%
# 49            7910  0.002528  0.25%
# 50            8051  0.003478  0.35%
# 51            8189  0.004640  0.46%
# 52            8269  0.003870  0.39%

# %%
# O indicador apresenta crescimento. Matematicamente, ou a quantidade de novas assinaturas esta diminuindo e/ou
# a quantidade de cancelamentos esta aumentando. Demnonstrando sua regressao linear:

# %%
Churn['X'] = np.arange(len(Churn))
Churn
# Out:
# <ipython-input-66-f2d20b4c88d4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Churn['X'] = np.arange(len(Churn))
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 6         201701     165          1                 12             1200
# 7         201702     145          2                 14             1345
# 8         201703     185          6                 20             1530
# 9         201704     169          2                 22             1699
# 10        201705     169          2                 24             1868
# 11        201706     170          3                 27             2038
# 12        201707     171          5                 32             2209
# 13        201709     161          4                 36             2370
# 14        201710     169          2                 38             2539
# 15        201711     144          4                 42             2683
# 16        201712     164          5                 47             2847
# 17        201801     188          6                 53             3035
# 18        201802     156          7                 60             3191
# 19        201803     172          3                 63             3363
# 20        201804     142          5                 68             3505
# 21        201805     157          3                 71             3662
# 22        201806     168          6                 77             3830
# 23        201807     153          4                 81             3983
# 24        201808     161          9                 90             4144
# 25        201809     162          5                 95             4306
# 26        201810     183          9                104             4489
# 27        201811     170         10                114             4659
# 28        201812     163          8                122             4822
# 29        201901     159          6                128             4981
# 30        201902     158          7                135             5139
# 31        201903     200         11                146             5339
# 32        201904     164         12                158             5503
# 33        201905     151          8                166             5654
# 34        201906     180         10                176             5834
# 35        201907     164          4                180             5998
# 36        201908     167          7                187             6165
# 37        201909     151         12                199             6316
# 38        201910     195          8                207             6511
# 39        201911     142         11                218             6653
# 40        201912     165         19                237             6818
# 41        202001     164         22                259             6982
# 42        202002     154         11                270             7136
# 43        202003     180         11                281             7316
# 44        202004     159         23                304             7475
# 45        202005     179         15                319             7654
# 46        202006     159         20                339             7813
# 47        202007     159         27                366             7972
# 48        202008     174         15                381             8146
# 49        202009     165         20                401             8311
# 50        202010     169         28                429             8480
# 51        202011     176         38                467             8656
# 52        202012     112         32                499             8768
#
#     SaldoAcumulado     Churn Churn%   X
# 6             1188  0.000842  0.08%   0
# 7             1331  0.001503  0.15%   1
# 8             1510  0.003974  0.40%   2
# 9             1677  0.001193  0.12%   3
# 10            1844  0.001085  0.11%   4
# 11            2011  0.001492  0.15%   5
# 12            2177  0.002297  0.23%   6
# 13            2334  0.001714  0.17%   7
# 14            2501  0.000800  0.08%   8
# 15            2641  0.001515  0.15%   9
# 16            2800  0.001786  0.18%  10
# 17            2982  0.002012  0.20%  11
# 18            3131  0.002236  0.22%  12
# 19            3300  0.000909  0.09%  13
# 20            3437  0.001455  0.15%  14
# 21            3591  0.000835  0.08%  15
# 22            3753  0.001599  0.16%  16
# 23            3902  0.001025  0.10%  17
# 24            4054  0.002220  0.22%  18
# 25            4211  0.001187  0.12%  19
# 26            4385  0.002052  0.21%  20
# 27            4545  0.002200  0.22%  21
# 28            4700  0.001702  0.17%  22
# 29            4853  0.001236  0.12%  23
# 30            5004  0.001399  0.14%  24
# 31            5193  0.002118  0.21%  25
# 32            5345  0.002245  0.22%  26
# 33            5488  0.001458  0.15%  27
# 34            5658  0.001767  0.18%  28
# 35            5818  0.000688  0.07%  29
# 36            5978  0.001171  0.12%  30
# 37            6117  0.001962  0.20%  31
# 38            6304  0.001269  0.13%  32
# 39            6435  0.001709  0.17%  33
# 40            6581  0.002887  0.29%  34
# 41            6723  0.003272  0.33%  35
# 42            6866  0.001602  0.16%  36
# 43            7035  0.001564  0.16%  37
# 44            7171  0.003207  0.32%  38
# 45            7335  0.002045  0.20%  39
# 46            7474  0.002676  0.27%  40
# 47            7606  0.003550  0.35%  41
# 48            7765  0.001932  0.19%  42
# 49            7910  0.002528  0.25%  43
# 50            8051  0.003478  0.35%  44
# 51            8189  0.004640  0.46%  45
# 52            8269  0.003870  0.39%  46

# %%
X = Churn.iloc[:, 8].values.reshape(-1, 1)

# %%
Y = Churn.iloc[:, 6].values.reshape(-1, 1)

# %%
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(X, Y)
# Out:
# LinearRegression()

# %%
Churn_pred = linear_regressor.predict(X)

# %%
print(linear_regressor.intercept_)
# Out:
# [0.00119524]

# %%
Churn
# Out:
#    created_at_YM  Criado  Deletados  DeletadoAcumulado  CriadoAcumulado  \
# 6         201701     165          1                 12             1200
# 7         201702     145          2                 14             1345
# 8         201703     185          6                 20             1530
# 9         201704     169          2                 22             1699
# 10        201705     169          2                 24             1868
# 11        201706     170          3                 27             2038
# 12        201707     171          5                 32             2209
# 13        201709     161          4                 36             2370
# 14        201710     169          2                 38             2539
# 15        201711     144          4                 42             2683
# 16        201712     164          5                 47             2847
# 17        201801     188          6                 53             3035
# 18        201802     156          7                 60             3191
# 19        201803     172          3                 63             3363
# 20        201804     142          5                 68             3505
# 21        201805     157          3                 71             3662
# 22        201806     168          6                 77             3830
# 23        201807     153          4                 81             3983
# 24        201808     161          9                 90             4144
# 25        201809     162          5                 95             4306
# 26        201810     183          9                104             4489
# 27        201811     170         10                114             4659
# 28        201812     163          8                122             4822
# 29        201901     159          6                128             4981
# 30        201902     158          7                135             5139
# 31        201903     200         11                146             5339
# 32        201904     164         12                158             5503
# 33        201905     151          8                166             5654
# 34        201906     180         10                176             5834
# 35        201907     164          4                180             5998
# 36        201908     167          7                187             6165
# 37        201909     151         12                199             6316
# 38        201910     195          8                207             6511
# 39        201911     142         11                218             6653
# 40        201912     165         19                237             6818
# 41        202001     164         22                259             6982
# 42        202002     154         11                270             7136
# 43        202003     180         11                281             7316
# 44        202004     159         23                304             7475
# 45        202005     179         15                319             7654
# 46        202006     159         20                339             7813
# 47        202007     159         27                366             7972
# 48        202008     174         15                381             8146
# 49        202009     165         20                401             8311
# 50        202010     169         28                429             8480
# 51        202011     176         38                467             8656
# 52        202012     112         32                499             8768
#
#     SaldoAcumulado     Churn Churn%   X
# 6             1188  0.000842  0.08%   0
# 7             1331  0.001503  0.15%   1
# 8             1510  0.003974  0.40%   2
# 9             1677  0.001193  0.12%   3
# 10            1844  0.001085  0.11%   4
# 11            2011  0.001492  0.15%   5
# 12            2177  0.002297  0.23%   6
# 13            2334  0.001714  0.17%   7
# 14            2501  0.000800  0.08%   8
# 15            2641  0.001515  0.15%   9
# 16            2800  0.001786  0.18%  10
# 17            2982  0.002012  0.20%  11
# 18            3131  0.002236  0.22%  12
# 19            3300  0.000909  0.09%  13
# 20            3437  0.001455  0.15%  14
# 21            3591  0.000835  0.08%  15
# 22            3753  0.001599  0.16%  16
# 23            3902  0.001025  0.10%  17
# 24            4054  0.002220  0.22%  18
# 25            4211  0.001187  0.12%  19
# 26            4385  0.002052  0.21%  20
# 27            4545  0.002200  0.22%  21
# 28            4700  0.001702  0.17%  22
# 29            4853  0.001236  0.12%  23
# 30            5004  0.001399  0.14%  24
# 31            5193  0.002118  0.21%  25
# 32            5345  0.002245  0.22%  26
# 33            5488  0.001458  0.15%  27
# 34            5658  0.001767  0.18%  28
# 35            5818  0.000688  0.07%  29
# 36            5978  0.001171  0.12%  30
# 37            6117  0.001962  0.20%  31
# 38            6304  0.001269  0.13%  32
# 39            6435  0.001709  0.17%  33
# 40            6581  0.002887  0.29%  34
# 41            6723  0.003272  0.33%  35
# 42            6866  0.001602  0.16%  36
# 43            7035  0.001564  0.16%  37
# 44            7171  0.003207  0.32%  38
# 45            7335  0.002045  0.20%  39
# 46            7474  0.002676  0.27%  40
# 47            7606  0.003550  0.35%  41
# 48            7765  0.001932  0.19%  42
# 49            7910  0.002528  0.25%  43
# 50            8051  0.003478  0.35%  44
# 51            8189  0.004640  0.46%  45
# 52            8269  0.003870  0.39%  46

# %%
plt.scatter(X, Y)
plt.plot(X, Churn_pred, color='red')
plt.title('Subscriber Churn')
plt.xlabel('# of months from May, 2016')
plt.ylabel('Churn')
plt.show()

# %%
print(linear_regressor.coef_)
# Out:
# [[3.30510275e-05]]

# %%
# Temos um grafico com os valores do Churn plotados ao longo do tempo e uma reta de regressao linear.
# É visivel uma inversao na tendencia dos valores a partir do mês 35, até onde se apresentava valores 
# praticiamente constantes no indicador.

# %%
# Diminuição de novas assinaturas e/ou o aumento de cancelamentos?

# %%
# Analisando novas assinaturas

# %%
X = Churn.iloc[:, 8].values.reshape(-1, 1)
Y = Churn.iloc[:, 1].values.reshape(-1, 1)
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Criadas_pred = linear_regressor.predict(X)
plt.scatter(X, Y)
plt.plot(X, Criadas_pred, color='red')
plt.title('Novos assinantes')
plt.xlabel('# of months from May, 2016')
plt.ylabel('Qtd')
plt.show()

# %%
print(linear_regressor.coef_)
# Out:
# [[-0.08094357]]

# %%
# Numero de novos assinantes permanece praticamente constante, com uma leve queda ao longo dos anos. 
# O baixo coeficiente de inclicacao -0,08 nos prova

# %%
# Então o numero de cancelamentos deve ser o principal item que elevou o valor do nosso indicador Churn

# %%
X = Churn.iloc[:, 8].values.reshape(-1, 1)
Y = Churn.iloc[:, 2].values.reshape(-1, 1)
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Deletadas_pred = linear_regressor.predict(X)
plt.scatter(X, Y)
plt.plot(X, Deletadas_pred, color='red')
plt.title('Assinaturas canceladas')
plt.xlabel('# of months from May, 2016')
plt.ylabel('Qtd')
plt.show()

# %%
print(linear_regressor.coef_)
# Out:
# [[0.51630435]]

# %%
# Atraves da analise do quantitativo de pessoas que cancelaram as assinaturas, observamos o mesmo comportamento 
# do nosso indicador Churn.
# Os valores de crescimento no numero de cancelamentos se mantem crescente e constante ate cerca do mes 32 meses, ou seja,
# por volta do mes de Dezembro de 2018.

# %%
# Estaria relacionado ao aumento de precos?

# %%
dados['X'] = np.arange(len(dados))
print(dados.columns)
# Out:
# Index(['id', 'created_at', 'updated_at', 'deleted_at', 'name_hash',
#        'email_hash', 'address_hash', 'birth_date', 'status', 'version', 'city',
#        'state', 'neighborhood', 'last_date_purchase', 'average_ticket',
#        'num_items', 'all_revenue', 'recency', 'marketing_source', 'Criado',
#        'created_at_YM', 'deleted_at_YM', 'X'],
#       dtype='object')

# %%
X = dados.iloc[:, 17].values.reshape(-1, 1)
Y = dados.iloc[:, 14].values.reshape(-1, 1)
linear_regressor = LinearRegression()
linear_regressor.fit(X, Y)
Ticket_medio_pred = linear_regressor.predict(X)
plt.scatter(X, Y)
plt.plot(X, Ticket_medio_pred, color='red')
plt.title('Ticket Médio')
plt.xlabel('# de dias de inatividade')
plt.ylabel('Valor')
plt.show()

# %%
# Notamos o ticket médio constante, não indicando causa do aumento de cancelamentos relacionado com os preços.

# %%
print(linear_regressor.coef_)
# Out:
# [[-7.89770917e-05]]

# %%
#Estaria relacionado a não utilização da assinatura? Ou seja, estaria as assinaturas sendo canceladas pelo fato de não #
#estar havendo compras?

# %%
boxplot = dados.boxplot(column=['recency'], by=['status'])

# %%
# Aqui temos o real motivo do cancelamento. Observando valores médios para q quantidade de dias sem a utilização 
# da assinatura. Enquanto valores médios de dias sem utilização para contas ativas e pausadas

# %%
plt.scatter(dados.X, dados.average_ticket)
plt.title('Ticket Médio ao longo das dads de criação da assinatura')
plt.xlabel('meses')
plt.ylabel('Valor')
plt.show()

# %%
# Nota-se que parece não haver uma campanha de descontos progressiva, pois analisando dos dados de ticket médio ao longo dos
# meses, este se mantem constante.

# %%
plt.scatter(dados.recency, dados.average_ticket)
plt.title('Ticket Médio ao longo do dias de inatividade das contas')
plt.xlabel('dias de inatividade')
plt.ylabel('Valor')
plt.show()

# %%
# Ticket médio para os dias de inatividade das contas também se mantem constante. 
# Sugerir campanha de descontos progressivos, incentivando a compra, diminuindo o período de inatividade e assim
# evitando novos cancelamentos e impulsionando
